# %%
import pandas as pd
import glob
import os

# %%
search_path = "data/*.csv" 
all_files = glob.glob(search_path, recursive=True)
processed_dfs = []
raster_files = [f for f in all_files if "raster_data" in f.lower()]

print(f"Found {len(raster_files)} files.")
# Out:
# Found 193 files.

# %%
processed_dfs = []
for filename in raster_files:
    df = pd.read_csv(filename) 
    site_id = filename.split('site')[1].replace('.csv', '')
    df.insert(0, 'site', site_id)
    processed_dfs.append(df)

data = pd.concat(processed_dfs, axis=0, ignore_index=True)
data.to_csv("data/data.csv", index=False)

# %%
raster_files
# Out:
# ['data\\raster_data_bert_am_site013.csv',
#  'data\\raster_data_bert_am_site014.csv',
#  'data\\raster_data_bert_am_site017.csv',
#  'data\\raster_data_bert_am_site018.csv',
#  'data\\raster_data_bert_am_site021.csv',
#  'data\\raster_data_bert_am_site025.csv',
#  'data\\raster_data_bert_am_site029.csv',
#  'data\\raster_data_bert_am_site033.csv',
#  'data\\raster_data_bert_am_site037.csv',
#  'data\\raster_data_bert_am_site041.csv',
#  'data\\raster_data_bert_am_site042.csv',
#  'data\\raster_data_bert_am_site045.csv',
#  'data\\raster_data_bert_am_site049.csv',
#  'data\\raster_data_bert_am_site050.csv',
#  'data\\raster_data_bert_am_site054.csv',
#  'data\\raster_data_bert_am_site065.csv',
#  'data\\raster_data_bert_am_site069.csv',
#  'data\\raster_data_bert_am_site070.csv',
#  'data\\raster_data_bert_am_site073.csv',
#  'data\\raster_data_bert_am_site074.csv',
#  'data\\raster_data_bert_am_site077.csv',
#  'data\\raster_data_bert_am_site085.csv',
#  'data\\raster_data_bert_am_site086.csv',
#  'data\\raster_data_bert_am_site089.csv',
#  'data\\raster_data_bert_am_site093.csv',
#  'data\\raster_data_bert_am_site097.csv',
#  'data\\raster_data_bert_am_site101.csv',
#  'data\\raster_data_bert_am_site105.csv',
#  'data\\raster_data_bert_am_site106.csv',
#  'data\\raster_data_bert_am_site110.csv',
#  'data\\raster_data_bert_am_site113.csv',
#  'data\\raster_data_bert_am_site121.csv',
#  'data\\raster_data_bert_am_site122.csv',
#  'data\\raster_data_bert_am_site125.csv',
#  'data\\raster_data_bert_am_site126.csv',
#  'data\\raster_data_bert_am_site127.csv',
#  'data\\raster_data_bert_am_site133.csv',
#  'data\\raster_data_bert_am_site135.csv',
#  'data\\raster_data_bert_am_site137.csv',
#  'data\\raster_data_bert_am_site138.csv',
#  'data\\raster_data_bert_am_site141.csv',
#  'data\\raster_data_bert_am_site142.csv',
#  'data\\raster_data_bert_am_site145.csv',
#  'data\\raster_data_bert_am_site146.csv',
#  'data\\raster_data_bert_am_site147.csv',
#  'data\\raster_data_bert_am_site149.csv',
#  'data\\raster_data_bert_am_site150.csv',
#  'data\\raster_data_bert_am_site151.csv',
#  'data\\raster_data_bert_am_site153.csv',
#  'data\\raster_data_bert_am_site154.csv',
#  'data\\raster_data_bert_am_site155.csv',
#  'data\\raster_data_bert_am_site157.csv',
#  'data\\raster_data_bert_am_site158.csv',
#  'data\\raster_data_bert_am_site161.csv',
#  'data\\raster_data_bert_am_site162.csv',
#  'data\\raster_data_bert_am_site166.csv',
#  'data\\raster_data_bert_am_site169.csv',
#  'data\\raster_data_bert_am_site170.csv',
#  'data\\raster_data_bert_am_site177.csv',
#  'data\\raster_data_bert_am_site181.csv',
#  'data\\raster_data_bert_am_site182.csv',
#  'data\\raster_data_bert_am_site183.csv',
#  'data\\raster_data_bert_am_site185.csv',
#  'data\\raster_data_bert_am_site186.csv',
#  'data\\raster_data_bert_am_site189.csv',
#  'data\\raster_data_bert_am_site190.csv',
#  'data\\raster_data_bert_am_site193.csv',
#  'data\\raster_data_bert_am_site194.csv',
#  'data\\raster_data_bert_am_site197.csv',
#  'data\\raster_data_bert_am_site201.csv',
#  'data\\raster_data_bert_am_site202.csv',
#  'data\\raster_data_bert_am_site205.csv',
#  'data\\raster_data_bert_am_site206.csv',
#  'data\\raster_data_bert_am_site209.csv',
#  'data\\raster_data_bert_am_site213.csv',
#  'data\\raster_data_bert_am_site217.csv',
#  'data\\raster_data_bert_am_site218.csv',
#  'data\\raster_data_bert_am_site221.csv',
#  'data\\raster_data_bert_am_site222.csv',
#  'data\\raster_data_bert_am_site225.csv',
#  'data\\raster_data_bert_am_site226.csv',
#  'data\\raster_data_bert_am_site229.csv',
#  'data\\raster_data_bert_am_site230.csv',
#  'data\\raster_data_bert_am_site233.csv',
#  'data\\raster_data_bert_am_site234.csv',
#  'data\\raster_data_bert_am_site235.csv',
#  'data\\raster_data_bert_am_site241.csv',
#  'data\\raster_data_bert_am_site245.csv',
#  'data\\raster_data_bert_am_site246.csv',
#  'data\\raster_data_bert_am_site249.csv',
#  'data\\raster_data_bert_am_site250.csv',
#  'data\\raster_data_bert_am_site253.csv',
#  'data\\raster_data_bert_am_site254.csv',
#  'data\\raster_data_bert_am_site257.csv',
#  'data\\raster_data_bert_am_site258.csv',
#  'data\\raster_data_bert_am_site261.csv',
#  'data\\raster_data_bert_am_site265.csv',
#  'data\\raster_data_bert_am_site293.csv',
#  'data\\raster_data_bert_am_site301.csv',
#  'data\\raster_data_bert_am_site305.csv',
#  'data\\raster_data_bert_am_site309.csv',
#  'data\\raster_data_bert_am_site313.csv',
#  'data\\raster_data_bert_am_site321.csv',
#  'data\\raster_data_bert_am_site325.csv',
#  'data\\raster_data_bert_am_site329.csv',
#  'data\\raster_data_bert_am_site333.csv',
#  'data\\raster_data_bert_am_site337.csv',
#  'data\\raster_data_bert_am_site341.csv',
#  'data\\raster_data_bert_am_site345.csv',
#  'data\\raster_data_bert_am_site349.csv',
#  'data\\raster_data_bert_am_site354.csv',
#  'data\\raster_data_bert_am_site357.csv',
#  'data\\raster_data_bert_am_site361.csv',
#  'data\\raster_data_bert_am_site365.csv',
#  'data\\raster_data_bert_am_site369.csv',
#  'data\\raster_data_bert_am_site373.csv',
#  'data\\raster_data_bert_am_site377.csv',
#  'data\\raster_data_bert_am_site381.csv',
#  'data\\raster_data_bert_am_site385.csv',
#  'data\\raster_data_bert_am_site386.csv',
#  'data\\raster_data_bert_am_site389.csv',
#  'data\\raster_data_bert_am_site390.csv',
#  'data\\raster_data_bert_am_site393.csv',
#  'data\\raster_data_bert_am_site397.csv',
#  'data\\raster_data_bert_am_site401.csv',
#  'data\\raster_data_bert_am_site402.csv',
#  'data\\raster_data_bert_am_site405.csv',
#  'data\\raster_data_bert_am_site409.csv',
#  'data\\raster_data_bert_am_site413.csv',
#  'data\\raster_data_bert_am_site421.csv',
#  'data\\raster_data_bert_am_site425.csv',
#  'data\\raster_data_bert_am_site429.csv',
#  'data\\raster_data_bert_am_site433.csv',
#  'data\\raster_data_bert_am_site437.csv',
#  'data\\raster_data_lupo_am_site005.csv',
#  'data\\raster_data_lupo_am_site009.csv',
#  'data\\raster_data_lupo_am_site021.csv',
#  'data\\raster_data_lupo_am_site025.csv',
#  'data\\raster_data_lupo_am_site026.csv',
#  'data\\raster_data_lupo_am_site029.csv',
#  'data\\raster_data_lupo_am_site030.csv',
#  'data\\raster_data_lupo_am_site045.csv',
#  'data\\raster_data_lupo_am_site057.csv',
#  'data\\raster_data_lupo_am_site058.csv',
#  'data\\raster_data_lupo_am_site065.csv',
#  'data\\raster_data_lupo_am_site066.csv',
#  'data\\raster_data_lupo_am_site070.csv',
#  'data\\raster_data_lupo_am_site073.csv',
#  'data\\raster_data_lupo_am_site074.csv',
#  'data\\raster_data_lupo_am_site077.csv',
#  'data\\raster_data_lupo_am_site081.csv',
#  'data\\raster_data_lupo_am_site093.csv',
#  'data\\raster_data_lupo_am_site094.csv',
#  'data\\raster_data_lupo_am_site098.csv',
#  'data\\raster_data_lupo_am_site101.csv',
#  'data\\raster_data_lupo_am_site102.csv',
#  'data\\raster_data_lupo_am_site109.csv',
#  'data\\raster_data_lupo_am_site110.csv',
#  'data\\raster_data_lupo_am_site113.csv',
#  'data\\raster_data_lupo_am_site114.csv',
#  'data\\raster_data_lupo_am_site118.csv',
#  'data\\raster_data_lupo_am_site121.csv',
#  'data\\raster_data_lupo_am_site122.csv',
#  'data\\raster_data_lupo_am_site123.csv',
#  'data\\raster_data_lupo_am_site125.csv',
#  'data\\raster_data_lupo_am_site129.csv',
#  'data\\raster_data_lupo_am_site133.csv',
#  'data\\raster_data_lupo_am_site138.csv',
#  'data\\raster_data_lupo_am_site145.csv',
#  'data\\raster_data_lupo_am_site149.csv',
#  'data\\raster_data_lupo_am_site153.csv',
#  'data\\raster_data_lupo_am_site157.csv',
#  'data\\raster_data_lupo_am_site161.csv',
#  'data\\raster_data_lupo_am_site162.csv',
#  'data\\raster_data_lupo_am_site163.csv',
#  'data\\raster_data_lupo_am_site169.csv',
#  'data\\raster_data_lupo_am_site173.csv',
#  'data\\raster_data_lupo_am_site174.csv',
#  'data\\raster_data_lupo_am_site177.csv',
#  'data\\raster_data_lupo_am_site181.csv',
#  'data\\raster_data_lupo_am_site182.csv',
#  'data\\raster_data_lupo_am_site193.csv',
#  'data\\raster_data_lupo_am_site197.csv',
#  'data\\raster_data_lupo_am_site201.csv',
#  'data\\raster_data_lupo_am_site205.csv',
#  'data\\raster_data_lupo_am_site206.csv',
#  'data\\raster_data_lupo_am_site209.csv',
#  'data\\raster_data_lupo_am_site210.csv',
#  'data\\raster_data_lupo_am_site213.csv',
#  'data\\raster_data_lupo_am_site221.csv',
#  'data\\raster_data_lupo_am_site222.csv',
#  'data\\raster_data_lupo_am_site223.csv',
#  'data\\raster_data_lupo_am_site225.csv']
