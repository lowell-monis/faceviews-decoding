# %% [markdown]
# # Decoding Faces and Orientations from Macaque AM Neural Activity
# ### December 5, 2025
#
# **Authors:** [Arkesh Das](https://www.linkedin.com/in/arkesh-das) and [Lowell Monis](https://www.linkedin.com/in/lowell-monis)
#
# This is a capstone of the methods, techniques, ideas, and processes that constitute the content covered in the second section of Computational Mathematics, Science, and Engineering 381, titled Fundamentals of Data Science Methods at Michigan State University during the fall semester of 2025. The project was conducted under the instruction of [Mengsen Zhang](https://directory.natsci.msu.edu/directory/Profiles/Person/104281), Ph. D., Assistant Professor of Computational Mathematics, Science, and Engineering, and Neuroscience, in partial fulfillment of the requirements of the course.
#
# ## Background and Motivation
#
# Face recognition is one of the most remarkable computational feats performed by the primate brain. It is difficult to comprehend how this neurological function takes place, for something that is very natural--an unimpressive process that happens every waking moment, but in reality is the sheer beauty of how primate brains work. Despite dramatic changes in viewing conditions--different lighting, distances, angles, and head orientations--we effortlessly recognize familiar individuals. This ability is so fundamental to primate social behavior that evolution has dedicated specialized neural machinery to solve it. Understanding how the brain achieves invariant face recognition remains a central question in neuroscience and has direct implications for artificial intelligence, as modern computer vision systems still struggle with the robustness that biological systems achieve naturally. Moreover, these application systems are very prone to bias, which makes improving the understanding of this intuitive primal process important while pursuing advancements in facial recognition technology.
#
# ### The Macaque Face-Processing System
#
# Neuroscience research has revealed that the macaque monkey brain contains a hierarchical network of six discrete face-selective regions, called "face patches," located in the temporal lobe. These regions were discovered through functional magnetic resonance imaging (fMRI) and confirmed through single-neuron recordings to contain neurons that respond much more strongly to faces than to other visual objects [1], [2].
#
# The face patch system is organized as a processing hierarchy with three main levels:
#
# - Posterior patches (PL): Initial face detection
# - Middle patches (ML/MF): View-specific feature extraction
# - Anterior patches (AL/AM): View-invariant identity representation
#
# The anterior medial (AM) face patch, which is the focus of our study, and the data we are using, courtesy to Friewald and Tsao [2], represents the apex of this hierarchy. Freiwald and Tsao [2] demonstrated that neurons in AM exhibit remarkable properties: they respond selectively to specific individuals across dramatically different head orientations: from full left profile to full right profile, from looking up to looking down. This "view-invariant" coding allows the monkey to recognize the same individual regardless of head pose, solving one of the fundamental challenges of object recognition.
#
# ### The Dataset: Neural Recordings from Face-Selective Neurons
#
# Our dataset consists of electrophysiological recordings from 193 individual neurons in the AM face patch of two macaque monkeys, Bert and Lupo. The experimental paradigm was simple yet powerful: monkeys passively viewed images of 25 different human individuals presented at 8 different head orientations:
#
# - left full profile
# - left three-quarter profile
# - frontal
# - right three-quarter profile
# - right full profile
# - upward
# - downward
# - back of head
#
# Each image was displayed for 200ms followed by a 200ms blank interval, while researchers recorded the precise timing of neural activity, which the authors call action potentials or "spikes".
#
# The data is organized in a "raster format"--a standard representation in neuroscience where each row corresponds to one trial (one presentation of a specific face image), and each column represents a 1-millisecond time bin spanning 800ms from stimulus onset. A value of 1 indicates the neuron fired an action potential during that millisecond; a value of 0 indicates the neuron was silent. This temporal precision allows us to track how neural representations evolve over time as visual information flows through the brain's processing hierarchy. Although neurons were recorded at different times, each neuron saw the same stimuli in the same order. This allows us to align trials across neurons and construct a pseudo population representation. This is common in neuroscience when neurons were not recorded simultaneously.
#
# This dataset was originally collected by Freiwald and Tsao and subsequently analyzed by Meyers et al. [3] using neural decoding techniques. Their work demonstrated that the AM population contains rich information about facial identity that generalizes across head poses, and that this pose-invariant information increases systematically from posterior to anterior face patches. Our project builds on this foundation by applying multiple machine learning methods to extract different aspects of information from these neural population responses.
#
# ### Objectives
#
# The neural activity patterns in the AM face patch encode multiple types of information simultaneously--which individual is being viewed, what orientation their head is in, etc. By applying different analytical methods, we can probe what information is present in these neural responses and how it is organized. Our project addresses the following questions:
#
# 1. **Can neural representations in the anterior medial region demonstrate an ability to recognize facial features at peak times?** We will train a support vector classification model to analyze whether peak times between 150-250ms has firing rates that can predict facial features well.
#
# 2. **Which stimulus dimensions--person identity versus head orientation--drive neural population responses most strongly?** While classification tells us what information can be extracted, regression approaches reveal what variables neural populations are actually encoding. By predicting the magnitude of neural responses from stimulus properties, we can quantify the relative importance of identity versus pose information and test whether AM prioritizes identity coding as the previous literature suggests. Essentially, we will inquire which stimulus dimensions, identity or orientation, best predict the strength of neural responses. We will use ridge regression applied to the mean firing rate extracted from the peak post-stimulus window.
#
# Both approaches build on prior findings from Freiwald and Tsao [2] and Meyers et al. [3].
#
# ## Methodology
#
# One can commence this analysis by importing standard libraries and packages that will be used in this project. We will also set a plotting style and palette.

# %%
import pandas as pd
import numpy as np
import glob
import os
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.cluster import KMeans
from sklearn.tree import DecisionTreeClassifier, plot_tree, export_text
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split, KFold, GridSearchCV, cross_val_score, RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import Ridge
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, mean_squared_error, r2_score
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")

# %% [markdown]
# Next, we will focus on importing and exploring our data. The data is provided to us in the form of rasters, with the rows denoting a trial and the columns denoting the time bins and other information identifying each trial. We will be concatenating these rasters. First, let's identify the number of comma-separated value files provided to us.

# %%
search_path = "data/*.csv" 
all_files = glob.glob(search_path, recursive=True)
processed_dfs = []
raster_files = [f for f in all_files if "raster_data" in f.lower()]

print(f"Found {len(raster_files)} files.")
# Out:
# Found 193 files.

# %% [markdown]
# We have found 193 rasters. Each raster represents a unique neural recording site on one of the two macaques. Below, one can find the concatenator function imported from the script `data_generator.py`. The cell below can be activated and run if one needs to generate a concatenated data file. This will take a signficant amount of time to complete. Post-generation, one can use the cell that follows to import the data as a CSV instead, since the generator saves a copy of the data in the `data` directory as `data.csv` by default. Set `save=False` if you would not like to save a copy of the data. The generator code used in `data_generator.py` can can be found in the [appendix](#data-concatenation-code).

# %% [raw]
# from data_generator import concatenate_rasters
#
# data=concatenate_rasters(save=True)

# %%
data = pd.read_csv("data/data.csv")

# %%
data.shape
# Out:
# (206216, 807)

# %% [markdown]
# One can conclude that there have been 206,216 trials across all of these 193 sites. It also looks like there are no missing values in the data.

# %%
null_count=data.isnull().sum()
null_count[null_count>0]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# Next, we can conduct sanity checks to verify if our data has been imported correctly by verifying facts with the literature. There are two monkeys, Bert and Lupo, and we only have the data for recording done on the anterior medial region, which is the scope of this analysis. There are 25 unique people whose facial orientations have been shown to the monkeys, with eight such orientations each. The data has time bins for 800ms, out of which only the first 400ms are relevant to our analysis, since most stimulus after the 400ms mark is not of much use as per the authors of the literature [2]. Restricting analyses to the first 400ms is standard practice and reduces the data size significantly. Only the first 400ms of each trial correspond to stimulus driven activity.

# %%
print(f"Monkeys: {data['site_info.monkey'].nunique()}")
print(f"Regions: {data['site_info.region'].unique()}")
print(f"People: {data['labels.person'].nunique()}")
print(f"Orientations: {data['labels.orientation'].nunique()}")
print(f"Time bins: {len([col for col in data.columns if col.startswith('time.')])}")
# Out:
# Monkeys: 2
# Regions: ['am']
# People: 25
# Orientations: 8
# Time bins: 800

# %% [markdown]
# From the sanity check, we can conclude that our data fits the literature.

# %%
le_person = LabelEncoder()
data['person_encoded'] = le_person.fit_transform(data['labels.person'])

le_orient = LabelEncoder()
data['orient_encoded'] = le_orient.fit_transform(data['labels.orientation'])
orientation_labels = le_orient.classes_

# %% [markdown]
# Considering we will be addressing classification problems, it is important to ensure that our classes are as balanced as possible to avoid introducing skewed models due to class imbalance. If classes are imbalanced, our methods need to use stratifications. To that end, let us visualize the breakdown of different classes in the data.

# %%
class_columns = ['labels.person', 'labels.orientation']
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(14, 6))
plt.suptitle('Class Distribution', fontsize=16)

for i, col in enumerate(class_columns):
    class_counts = data[col].value_counts().sort_index()
    class_counts.plot(kind='bar', ax=axes[i], rot=45)
    axes[i].set_title(f'Distribution for: {col}', fontsize=12)
    axes[i].set_ylabel('Number of Samples')
    axes[i].set_xlabel(col)

# %% [markdown]
# All of our classes look almost identical in magnitude with very little variation. The classes are almost balanced, and hence there is no explicit need for stratification. Next, we will be splitting our columns into various windows. We will then compute the column-wise means of the trials within these ranges.
#
# For work involving support vector machines, we decided to use data aggregated horizontally to cut down on training time by reducing the number of rows. We will be aggregating the spike means over all trials grouped by site (neuron), the macaque, person and their facial orientation visualized. We are include details about the macaque since both Lupo and Bert can have sites with the same numerical code. A verification of this can be shown when calculating the number of unique site numbers. The number is less than 193, which is indicative of our concern.

# %%
data['site'].nunique()
# Out:
# 155

# %%
site_counts = data['site'].value_counts()
grouping_cols = ['site', 'site_info.monkey', 'person_encoded', 'orient_encoded']
time_cols = [col for col in data.columns if col.startswith('time.')] 
aggregated_data = data.groupby(grouping_cols)[time_cols].mean().reset_index()
aggregated_data.shape
# Out:
# (38581, 804)

# %% [markdown]
# It looks like there are 38,581 unique combinations of sites.
#
# This will still take a long time to train a SVC. To that end, we will equitably sample 5000 site combinations from both Lupo and Bert.

# %%
bert_data = aggregated_data[aggregated_data['site_info.monkey'] == 'bert'].sample(n=2500, random_state=381)
lupo_data = aggregated_data[aggregated_data['site_info.monkey'] == 'lupo'].sample(n=2500, random_state=381)
aggregated_data = pd.concat([bert_data, lupo_data], ignore_index=True)

# %%
class_columns = ['person_encoded', 'orient_encoded']
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(14, 6))
plt.suptitle('Class Distribution', fontsize=16)

for i, col in enumerate(class_columns):
    class_counts = aggregated_data[col].value_counts().sort_index()
    class_counts.plot(kind='bar', ax=axes[i], rot=45)
    axes[i].set_title(f'Distribution for: {col}', fontsize=12)
    axes[i].set_ylabel('Number of Samples')
    axes[i].set_xlabel(col)

# %% [markdown]
# Class balance was not affected very harshly. Thus, we can proceed to prepare our analysis to answer the first question: Can firing rates at peak times (150ms to 250ms) be used to recognize facial features, particularly if one uses support vector classifiers?
#
# Next, we will subset into the peak window as dictated by the literature. All time bins post 400ms are redundant, considering they hardly have any firing values available, agreeing with the literature. We will instead focus on 150-250ms which is the peak window, where most of the decoding happens post-stimulus [3]. This also eliminates noise in the data.
#
# Visual information requires approximately 100ms to propagate from the retina through the visual hierarchy to reach the anterior medial (AM) face patch [2]. Prior studies have shown that face-selective responses in AM emerge around 100-150ms post-stimulus onset, with peak identity information occurring between 150-300ms [3]. Including the 0-100ms period would incorporate neural activity that reflects pre-stimulus baseline firing and non-specific visual onset responses rather than face-specific identity information.

# %%
peak_window = [f'time.{i}_{i+1}' for i in range(150, 250)]

# %% [markdown]
# The aggregated firing values in the peak window are the features we are considering for the support vector classifier to address the first question. The response will be determining the person being identified/decoded.

# %%
X = aggregated_data[peak_window].values
y = aggregated_data['person_encoded'].values
orientation = aggregated_data['orient_encoded'].values

# %% [markdown]
# Next, we will scale the data in preparation for support vector classification.

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
print(f"Mean after scaling: {X_scaled.mean():.4f}")
print(f"Standard deviation after scaling: {X_scaled.std():.4f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 2
#       1 scaler = StandardScaler()
# ----> 2 X_scaled = scaler.fit_transform(X)
#       3 print(f"Mean after scaling: {X_scaled.mean():.4f}")
#       4 print(f"Standard deviation after scaling: {X_scaled.std():.4f}")
#
# NameError: name 'X' is not defined

# %% [markdown]
# The data has been standardized perfectly and is now in the form $X\sim\mathcal{N}(0,1)$. We will now proceed with a train-test split.

# %%
X_train, X_test, y_train, y_test, orient_train, orient_test = train_test_split(
    X_scaled, y, orientation,
    test_size=0.2,
    stratify=y,
    random_state=381
)

# %%
print(f"Training samples: {X_train.shape[0]:,} ({X_train.shape[0]/len(X)*100:.1f}%)")
print(f"Test samples: {X_test.shape[0]:,} ({X_test.shape[0]/len(X)*100:.1f}%)")
# Out:
# Training samples: 4,000 (80.0%)
# Test samples: 1,000 (20.0%)

# %% [markdown]
# We will first train a baseline classifier model to gain an idea of what we are dealing with before we attempt to improve the model. We will use default parameters and a linear kernel.

# %%
svc_baseline = SVC(kernel='linear', random_state=381, max_iter=2000)
svc_baseline.fit(X_train, y_train)
y_pred = svc_baseline.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.047

# %% [markdown]
# As expected of a very baseline model, the accuracy is terrible. We will now proceed with a grid search cross-validation hyperparameter tuning to find the best possible parameters.
#
# We will tune hyperparameters `C` and `kernel`. Let's initiate the parameter grid and conduct the tuning. We will choose from either the linear or radial kernel, with grids initiated for each of them. $5$-fold cross-validation will be used.

# %%
kernels = ['linear', 'rbf', 'poly']
tuned_results = {}
best_models = {}
for kernel in kernels:
    print(f"\n{kernel.upper()}")
    if kernel == 'linear':
        param_grid = {
            'C': [0.01, 0.1, 1.0],
            'kernel': ['linear']
        }
    elif kernel == 'rbf':
        param_grid = {
            'C': [0.1, 1.0, 10.0],
            'gamma': ['scale', 'auto', 0.01, 0.1],
            'kernel': ['rbf']
        }
    elif kernel == 'poly':
        param_grid = {
            'C': [0.1, 1.0, 10.0],
            'degree': [2, 3, 4],
            'gamma': ['scale', 'auto'],
            'kernel': ['poly']
        }
    
    print(f"Parameter grid:")
    for param, values in param_grid.items():
        if param != 'kernel':
            print(f"{param}: {values}")
    
    total_combinations = np.prod([len(v) for k, v in param_grid.items() if k != 'kernel'])
    print(f"Total combinations: {total_combinations}")
    
    svm = SVC(random_state=42, max_iter=2000)
    kf = KFold(n_splits=5, shuffle=True, random_state=381)
    
    grid_search = GridSearchCV(
        estimator=svm,
        param_grid=param_grid,
        cv=kf,
        scoring='accuracy'
    )
    grid_search.fit(X_train, y_train)
    best_model = grid_search.best_estimator_
    y_pred = best_model.predict(X_test)
    test_acc = accuracy_score(y_test, y_pred)
    tuned_results[kernel] = {
        'best_params': grid_search.best_params_,
        'cv_score': grid_search.best_score_,
        'test_accuracy': test_acc
    }
    best_models[kernel] = best_model
    print(f"\n{kernel.upper()} Results:")
    print(f"Best params: {grid_search.best_params_}")
    print(f"Best CV score: {grid_search.best_score_*100:.2f}%")
    print(f"Test accuracy: {test_acc*100:.2f}%")

best_kernel_overall = max(tuned_results, key=lambda k: tuned_results[k]['test_accuracy'])
svm_best = best_models[best_kernel_overall]
# Out:
# LINEAR
# Parameter grid:
# C: [0.01, 0.1, 1.0]
# Total combinations: 3
#
# LINEAR Results:
# Best params: {'C': 0.01, 'kernel': 'linear'}
# Best CV score: 4.20%
# Test accuracy: 3.50%
#
# RBF
# Parameter grid:
# C: [0.1, 1.0, 10.0]
# gamma: ['scale', 'auto', 0.01, 0.1]
# Total combinations: 12
#
# RBF Results:
# Best params: {'C': 10.0, 'gamma': 'scale', 'kernel': 'rbf'}
# Best CV score: 4.58%
# Test accuracy: 4.50%
#
# POLY
# Parameter grid:
# C: [0.1, 1.0, 10.0]
# degree: [2, 3, 4]
# gamma: ['scale', 'auto']
# Total combinations: 18
#
# POLY Results:
# Best params: {'C': 0.1, 'degree': 4, 'gamma': 'scale', 'kernel': 'poly'}
# Best CV score: 4.50%
# Test accuracy: 4.90%

# %% [markdown]
# Let's checkout the most optimal model.

# %%
print(f"Best kernel: {best_kernel_overall}")
print(f"Parameters: {tuned_results[best_kernel_overall]['best_params']}")
print(f"CV accuracy: {tuned_results[best_kernel_overall]['cv_score']*100:.2f}%")
print(f"Test accuracy: {tuned_results[best_kernel_overall]['test_accuracy']*100:.2f}%")
# Out:
# Best kernel: poly
# Parameters: {'C': 0.1, 'degree': 4, 'gamma': 'scale', 'kernel': 'poly'}
# CV accuracy: 4.50%
# Test accuracy: 4.90%

# %% [markdown]
# While this is still a low accuracy, it is more optimal than the baseline.

# %% [markdown]
# Next, we will address the second question.
#
# Can we predict how strongly AM neurons respond to a given stimulus based solely on who the person is and what head orientation is presented? Which of these stimulus dimensions accounts for more variance in neural firing rate? This method provides a quantitative test of whether identity or orientation exerts a stronger influence on stimulus driven response magnitude in the AM region.
#
# First, we will use the original form of the data set and aggregate the mean firing rate for only the peak window bins.

# %%
data["mean_peak"] = data[peak_window].mean(axis=1)
plt.figure(figsize=(6, 4))
plt.hist(data["mean_peak"], bins=30)
plt.xlabel("Mean firing rate, 150–250 ms")
plt.ylabel("Count")
plt.title("Distribution of mean firing rate across trials for peak response time")
plt.show()

# %% [markdown]
# Most trials produce extremely low firing in the 150–250ms window, with a long right tail corresponding to identity specific bursts. This sparse distribution means our regression task involves predicting small, noisy fluctuations in firing rate, which is expected for AM neurons.
#
# Next, we will build a predictor matrix and outcome vector, where the outcome is the mean firing rate, and the predictor space is a denotation of the people and the facial orientations via one-hot encoding.

# %%
person_dummies = pd.get_dummies(data["labels.person"], prefix="person")
orient_dummies = pd.get_dummies(data["labels.orientation"], prefix="orient")

X = pd.concat([person_dummies, orient_dummies], axis=1)
y = data["mean_peak"].values

# %% [markdown]
# We will now check the correlation between the mean firing rate and the person via visual.

# %%
sns.boxplot(x=data["labels.person"], y=data["mean_peak"])
plt.xticks(rotation=90)
plt.xlabel("Person")
plt.ylabel("Mean firing rate, 150–250 ms")
plt.title("Mean firing rate by person (single neuron trials)")
plt.tight_layout()
plt.show()

# %% [markdown]
# This plot confirms that AM neurons show the classic sparse and highly selective firing pattern reported in the literature [2]. For almost every identity, the median response is near zero, meaning most neurons stay quiet, while a small number of trials produce very large responses from a handful of strongly tuned units. Each identity evokes only small responses in most neurons, with a few large outliers corresponding to highly selective cells. This matches the known sparse coding properties of the anterior medial face patch and is consistent with the idea that identity information is carried by small subpopulations rather than by the full neural ensemble.
#
# We can now proceed with a train-test split.

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    random_state=381,
    stratify=data["labels.person"]
)

print(f"Training samples: {X_train.shape[0]:,} ({X_train.shape[0]/len(X)*100:.1f}%)")
print(f"Test samples: {X_test.shape[0]:,} ({X_test.shape[0]/len(X)*100:.1f}%)")
# Out:
# Training samples: 164,972 (80.0%)
# Test samples: 41,244 (20.0%)

# %% [markdown]
# We can now look over a range of alpha values on a log scale and use k fold CV with MSE.

# %%
alphas = np.logspace(-3, 3, 15)  
kf = KFold(n_splits=5, shuffle=True, random_state=381)

cv_mse_means = []

for a in alphas:
    ridge = Ridge(alpha=a)
    scores = cross_val_score(
        ridge,
        X_train,
        y_train,
        scoring="neg_mean_squared_error",
        cv=kf
    )
    cv_mse_means.append(-np.mean(scores))

cv_mse_means = np.array(cv_mse_means)

best_idx = np.argmin(cv_mse_means)
best_alpha = alphas[best_idx]

print("Best alpha:", best_alpha)
print("CV MSE at best alpha:", cv_mse_means[best_idx])
# Out:
# Best alpha: 1000.0
# CV MSE at best alpha: 0.00018017126994387232

# %% [markdown]
# We will now visualize cross-validation error against potential $\alpha$ values.

# %%
plt.figure(figsize=(6, 4))
plt.semilogx(alphas, cv_mse_means, marker="o")
plt.axvline(best_alpha, color="red", linestyle="--", label=f"best alpha = {best_alpha:.3g}")
plt.xlabel("alpha (log scale)")
plt.ylabel("CV MSE")
plt.title("Ridge regression, CV error vs alpha")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# This cross validation curve shows that the ridge penalty needs to be large to control overfitting. The CV error decreases as alpha increases, and the optimal value is around alpha = 1000. This reflects the fact that the underlying signal is extremely weak, so strong regularization forces the model toward stable but very small coefficients.

# %% [markdown]
# Fitted ridge with the chosen alpha on the training set and evaluate on both train and test.

# %%
best_ridge = Ridge(alpha=best_alpha)
best_ridge.fit(X_train, y_train)

y_train_pred = best_ridge.predict(X_train)
y_test_pred = best_ridge.predict(X_test)

train_mse = mean_squared_error(y_train, y_train_pred)
test_mse = mean_squared_error(y_test, y_test_pred)
train_r2 = r2_score(y_train, y_train_pred)
test_r2 = r2_score(y_test, y_test_pred)

print(f"Train MSE: {train_mse:.4f}, Train R^2: {train_r2:.4f}")
print(f"Test MSE:  {test_mse:.4f}, Test R^2:  {test_r2:.4f}")
# Out:
# Train MSE: 0.0002, Train R^2: 0.0044
# Test MSE:  0.0002, Test R^2:  0.0036

# %% [markdown]
# Ridge regression explains less than one percent of the variance in population firing rate. This confirms that identity coding in AM is sparse and not linearly predictable from stimulus labels alone. This matches Freiwald & Tsao’s finding that only a subset of neurons carries strong identity signals, and highlights that mean firing rate is not the dominant representational dimension in AM.

# %%
plt.figure(figsize=(5, 5))
plt.scatter(y_test, y_test_pred, alpha=0.3)
min_val = min(y_test.min(), y_test_pred.min())
max_val = max(y_test.max(), y_test_pred.max())
plt.plot([min_val, max_val], [min_val, max_val], "r--")
plt.xlabel("Actual mean_peak")
plt.ylabel("Predicted mean_peak")
plt.title("Ridge regression, test set\nPredicted vs actual")
plt.tight_layout()
plt.show()

# %% [markdown]
# The predicted values cluster near zero regardless of the actual peak firing rate, which confirms that the ridge model explains almost none of the variance in single neuron firing. This matches expectations because mean firing rates are extremely small and vary only slightly across stimuli, making them difficult to predict with a linear model.

# %% [markdown]
# We will now build a dataframe of coefficients then sorted and plotted the most important ones (sorted by absolute value of the coefficient).

# %%
coef_df = pd.DataFrame({
    "feature": X.columns,
    "coef": best_ridge.coef_
})
coef_df["abs_coef"] = coef_df["coef"].abs()

coef_sorted = coef_df.sort_values("abs_coef", ascending=False)

coef_sorted.head(10)
# Out:
#                  feature      coef  abs_coef
# 25           orient_back -0.001445  0.001445
# 27          orient_front  0.001055  0.001055
# 29   orient_left profile -0.000714  0.000714
# 32             orient_up  0.000711  0.000711
# 26           orient_down  0.000685  0.000685
# 31  orient_right profile -0.000510  0.000510
# 14             person_15 -0.000469  0.000469
# 5               person_6  0.000466  0.000466
# 11             person_12  0.000449  0.000449
# 13             person_14  0.000438  0.000438

# %% [markdown]
# The largest coefficients were associated with orientation categories rather than identity categories. Even these effects were extremely small (absolute values all below 0.0015), consistent with the very weak R² values. Ridge shrinks weights and the design matrix contains only categorical indicators, so individual coefficients do not correspond to meaningful tuning in a biological sense. The pattern simply suggests that orientation explains slightly more variance in the mean firing rate than identity, but overall both contributions are negligible.

# %%
top_n = 15

person_coef = coef_sorted[coef_sorted["feature"].str.startswith("person")].head(top_n)

plt.figure(figsize=(8, 4))
sns.barplot(x="feature", y="coef", data=person_coef)
plt.xticks(rotation=90)
plt.xlabel("Person dummy feature")
plt.ylabel("Ridge coefficient")
plt.title(f"Top {top_n} person coefficients")
plt.tight_layout()
plt.show()

# %% [markdown]
# The ridge coefficients for person identity are all very close to zero. This indicates that identity has almost no linear effect on the peak firing rate in this time window. The tiny positive and negative values reflect noise rather than meaningful tuning, which is consistent with sparse selectivity in AM neurons.

# %%
orient_coef = coef_sorted[coef_sorted["feature"].str.startswith("orient")]

plt.figure(figsize=(6, 4))
sns.barplot(x="feature", y="coef", data=orient_coef)
plt.xticks(rotation=45)
plt.xlabel("Orientation dummy feature")
plt.ylabel("Ridge coefficient")
plt.title("Orientation coefficients in Ridge model")
plt.tight_layout()
plt.show()

# %% [markdown]
# Orientation coefficients are likewise extremely small, showing that head orientation only weakly influences mean firing rate in this linear model. Small deviations from zero do not represent strong coding but reflect minor shifts captured by ridge before shrinkage dominates.

# %% [markdown]
# Before interpreting the full ridge regression model, I thought it would be useful to measure how much variance in neural firing can be explained by identity features alone or orientation features alone. This comparison would hellp clarify whether one stimulus dimension contributes more predictive signal than the other, and it provides a simple sanity check on how much structure is present in the mean firing rate.
#
# To do this, we fitted three separate models, each using the same ridge regression framework. One had only identity dummy variables, one had only orientation dummy variables, one was the and the full model with all predictors.
# The resulting test set $R^2$ values give a direct comparison of how strongly each stimulus dimension relates to firing rate in this linear formulation

# %%
X_person = person_dummies
X_orient = orient_dummies

Xp_train, Xp_test, yp_train, yp_test = train_test_split(
    X_person, y, test_size=0.2, random_state=381, stratify=data["labels.person"]
)

Xo_train, Xo_test, yo_train, yo_test = train_test_split(
    X_orient, y, test_size=0.2, random_state=381, stratify=data["labels.person"]
)

ridge_person = Ridge(alpha=best_alpha)
ridge_person.fit(Xp_train, yp_train)
yp_pred = ridge_person.predict(Xp_test)
r2_person = r2_score(yp_test, yp_pred)

ridge_orient = Ridge(alpha=best_alpha)
ridge_orient.fit(Xo_train, yo_train)
yo_pred = ridge_orient.predict(Xo_test)
r2_orient = r2_score(yo_test, yo_pred)

print(f"Test R^2, person only:      {r2_person:.4f}")
print(f"Test R^2, orientation only: {r2_orient:.4f}")
print(f"Test R^2, full model:       {test_r2:.4f}")
# Out:
# Test R^2, person only:      0.0005
# Test R^2, orientation only: 0.0031
# Test R^2, full model:       0.0036

# %% [markdown]
# The orientation only model explains slightly more variance than the identity only model, but both R² values remain extremely small. This indicates that neither stimulus dimension has a strong linear relationship with the mean firing rate, and the improvement from combining both is minimal. These results are consistent with sparse and nonlinear coding in AM neurons, where identity and orientation effects are not well captured by simple linear rate models.
#
# Next

# %%
relevant_window = [f'time.{i}_{i+1}' for i in range(0, 400)]

bin_starts = range(1, 400, 50)
data_fr = pd.DataFrame(index=data.index)
    
for start in bin_starts:
    end = start + 50
    bin_cols = [f'time.{i}_{i+1}' for i in range(start, end)]
    spike_sum = data[bin_cols].sum(axis=1)
    firing_rate = spike_sum / (50 / 1000)
    data_fr[f'rate_{start}_{end}ms'] = firing_rate

print(f"Firing rate features shape: {data_fr.shape}")
print(f"Feature names: {data_fr.columns.tolist()}")
# Out:
# Firing rate features shape: (206216, 8)
# Feature names: ['rate_1_51ms', 'rate_51_101ms', 'rate_101_151ms', 'rate_151_201ms', 'rate_201_251ms', 'rate_251_301ms', 'rate_301_351ms', 'rate_351_401ms']

# %%
metadata_cols = ['site', 'site_info.monkey', 'site_info.region', 
                 'labels.person', 'labels.orientation', 'labels.stimID']
feature_cols = data_fr.columns.tolist()
data_cluster = pd.concat([data[metadata_cols], data_fr], axis=1).groupby(['labels.person', 'labels.orientation'])[feature_cols].mean().reset_index()

# %%
X_cluster=data_cluster[feature_cols].values
labels_person = data_cluster['labels.person'].values
labels_orientation = data_cluster['labels.orientation'].values
print("Clustering feature matrix:")
print(f"X shape: {X_cluster.shape}")
print(f"Rows: {X_cluster.shape[0]}")
print(f"Columns (time bins): {X_cluster.shape[1]}")
# Out:
# Clustering feature matrix:
# X shape: (200, 8)
# Rows: 200
# Columns (time bins): 8

# %%
X_scaled = scaler.fit_transform(X_cluster)
print(f"Original mean: {X_cluster.mean():.3f}, std: {X_cluster.std():.3f}")
print(f"Scaled mean: {X_scaled.mean():.3f}, std: {X_scaled.std():.3f}")
# Out:
# Original mean: 5.459, std: 1.451
# Scaled mean: -0.000, std: 1.000

# %%
pca = PCA()
X_pca = pca.fit_transform(X_scaled)
explained_variance = pca.explained_variance_ratio_
cumulative_variance = np.cumsum(explained_variance)
print(f"Number of PCs needed for 95% variance: {np.argmax(cumulative_variance >= 0.95) + 1}")
# Out:
# Number of PCs needed for 95% variance: 6

# %%
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(range(1, len(explained_variance)+1), cumulative_variance, marker='o')
plt.axhline(y=0.95, color='r', linestyle='--', label='95% variance')
plt.axvline(x=6, color='r', linestyle='--')
plt.xlabel('Number of Principal Components')
plt.ylabel('Cumulative Explained Variance')
plt.legend()

plt.subplot(1, 2, 2)
plt.bar(range(1, min(11, len(explained_variance)+1)), 
        explained_variance[:10])
plt.xlabel('Principal Component')
plt.ylabel('Variance Explained')

plt.tight_layout()
plt.show()

# %%
orientation_codes = le_orientation.fit_transform(labels_orientation)
person_codes = le_person.fit_transform(labels_person)
plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
scatter1 = plt.scatter(X_pca[:, 0], X_pca[:, 1], 
                       c=orientation_codes, 
                       cmap='tab10', s=100, alpha=0.7, edgecolors='k')
plt.xlabel(f'PC1 ({explained_variance[0]:.1%} variance)')
plt.ylabel(f'PC2 ({explained_variance[1]:.1%} variance)')
plt.title('Neural Responses Colored by Head Orientation')
plt.colorbar(scatter1, label='Orientation')
plt.grid(alpha=0.3)

plt.subplot(1, 2, 2)
scatter2 = plt.scatter(X_pca[:, 0], X_pca[:, 1], 
                       c=labels_person, cmap='tab20', 
                       s=100, alpha=0.7, edgecolors='k')
plt.xlabel(f'PC1 ({explained_variance[0]:.1%} variance)')
plt.ylabel(f'PC2 ({explained_variance[1]:.1%} variance)')
plt.title('Neural Responses Colored by Person Identity')
plt.colorbar(scatter2, label='Person ID')
plt.grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %%
k_range = range(2, 26)
wcss = []

for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=381, n_init=10)
    kmeans.fit(X_scaled)
    wcss.append(kmeans.inertia_)

plt.plot(k_range, wcss, marker='o', linewidth=2, markersize=8)
plt.axvline(x=8, color='r', linestyle='--', alpha=0.7, label='k=8 (orientations)')
plt.axvline(x=25, color='b', linestyle='--', alpha=0.7, label='k=25 (persons)')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Within-cluster Sum of Squares')
plt.title(r'Elbow Method: Finding Optimal $k$')
plt.legend()
plt.tight_layout()

# %%
kmeans_8 = KMeans(n_clusters=8, random_state=381, n_init=20)
clusters_8 = kmeans_8.fit_predict(X_scaled)
plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
scatter1 = plt.scatter(X_pca[:, 0], X_pca[:, 1], 
                       c=clusters_8, cmap='tab10', 
                       s=100, alpha=0.7, edgecolors='k')
plt.xlabel(f'PC1 ({explained_variance[0]:.1%} variance)')
plt.ylabel(f'PC2 ({explained_variance[1]:.1%} variance)')
plt.title(f'K-means Clusters (k=8)')
plt.colorbar(scatter1, label='Cluster')
plt.grid(alpha=0.3)

plt.subplot(1, 2, 2)
scatter2 = plt.scatter(X_pca[:, 0], X_pca[:, 1], 
                       c=orientation_codes, 
                       cmap='tab10', s=100, alpha=0.7, edgecolors='k')
plt.xlabel(f'PC1 ({explained_variance[0]:.1%} variance)')
plt.ylabel(f'PC2 ({explained_variance[1]:.1%} variance)')
plt.title(f'True Orientation Labels')
plt.colorbar(scatter2, label='Orientation')
plt.grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %%
kmeans_2 = KMeans(n_clusters=2, random_state=381, n_init=20)
clusters_2 = kmeans_2.fit_predict(X_scaled)
kmeans_3 = KMeans(n_clusters=3, random_state=381, n_init=20)
clusters_3 = kmeans_3.fit_predict(X_scaled)
plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
scatter1 = plt.scatter(X_pca[:, 0], X_pca[:, 1], 
                       c=clusters_2, cmap='tab10', 
                       s=100, alpha=0.7, edgecolors='k')
plt.xlabel(f'PC1 ({explained_variance[0]:.1%} variance)')
plt.ylabel(f'PC2 ({explained_variance[1]:.1%} variance)')
plt.title(f'K-means Clusters (k=2)')
plt.colorbar(scatter1, label='Cluster')
plt.grid(alpha=0.3)

plt.subplot(1, 2, 2)
scatter2 = plt.scatter(X_pca[:, 0], X_pca[:, 1], 
                       c=clusters_3, cmap='tab10', 
                       s=100, alpha=0.7, edgecolors='k')
plt.xlabel(f'PC1 ({explained_variance[0]:.1%} variance)')
plt.ylabel(f'PC2 ({explained_variance[1]:.1%} variance)')
plt.title(f'K-means Clusters (k=3)')
plt.colorbar(scatter2, label='Cluster')
plt.grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %%
data_tree = pd.concat([data[metadata_cols], data_fr], axis=1)
X = data_tree[feature_cols].values
y = data_tree['labels.orientation'].values
print(f"X shape: {X.shape}")
print(f"y shape: {y.shape}")
print(f"Number of classes: {len(np.unique(y))}")
# Out:
# X shape: (206216, 8)
# y shape: (206216,)
# Number of classes: 8

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.3,
    random_state=381,
    stratify=y
)

print(f"X_train shape: {X_train.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"Classes in train: {len(np.unique(y_train))}")
print(f"Classes in test: {len(np.unique(y_test))}")
# Out:
# X_train shape: (144351, 8)
# X_test shape: (61865, 8)
# Classes in train: 8
# Classes in test: 8

# %%
dt_baseline = DecisionTreeClassifier(random_state=42)

dt_baseline.fit(X_train, y_train)

y_pred_baseline = dt_baseline.predict(X_test)
baseline_acc = accuracy_score(y_test, y_pred_baseline)

print(f"Accuracy: {baseline_acc:.4f}")
print(f"Tree depth: {dt_baseline.get_depth()}")
print(f"Number of leaves: {dt_baseline.get_n_leaves()}")
print(f"Total nodes: {dt_baseline.tree_.node_count}")
# Out:
# Accuracy: 0.1381
# Tree depth: 33
# Number of leaves: 9764
# Total nodes: 19527

# %%
param_grid = {
    'max_depth': [5, 10, 15, 20, 25, 30, None]
}

dt_grid = GridSearchCV(
    DecisionTreeClassifier(random_state=381),
    param_grid=param_grid,
    cv=5,
    scoring='accuracy'
)

dt_grid.fit(X_train, y_train)

for param, value in dt_grid.best_params_.items():
    print(f"{param}: {value}")

print(f"Best CV score: {dt_grid.best_score_:.4f}")
# Out:
# max_depth: 5
# Best CV score: 0.1407

# %%
dt_pruned = dt_grid.best_estimator_
y_pred_pruned = dt_pruned.predict(X_test)
pruned_acc = accuracy_score(y_test, y_pred_pruned)
print(f"Test Accuracy: {pruned_acc:.4f}")
print(f"Baseline Accuracy: {baseline_acc:.4f}")
print(f"Improvement: {(pruned_acc - baseline_acc):.4f}")
print(f"Tree depth: {dt_pruned.get_depth()}")
print(f"Number of leaves: {dt_pruned.get_n_leaves()}")
print(f"Reduction in nodes: {dt_baseline.tree_.node_count - dt_pruned.tree_.node_count}")

print("Classification Report:")
print(classification_report(y_test, y_pred_pruned, digits=3))
# Out:
# Test Accuracy: 0.1431
# Baseline Accuracy: 0.1381
# Improvement: 0.0050
# Tree depth: 5
# Number of leaves: 32
# Reduction in nodes: 19464
# Classification Report:
#                precision    recall  f1-score   support
#
#          back      0.143     0.700     0.238      7807
#          down      0.142     0.136     0.139      7674
#         front      0.145     0.076     0.100      7707
#      left 3/4      0.123     0.011     0.020      7694
#  left profile      0.000     0.000     0.000      7710
#     right 3/4      0.179     0.007     0.014      7698
# right profile      0.184     0.002     0.004      7848
#            up      0.143     0.207     0.169      7727
#
#      accuracy                          0.143     61865
#     macro avg      0.133     0.142     0.085     61865
#  weighted avg      0.133     0.143     0.086     61865

# %%
plt.figure(figsize=(20, 10))
plot_tree(dt_pruned, 
          feature_names=feature_cols,
          filled=True,
          fontsize=10)
plt.title('Decision Tree Visualization')
plt.tight_layout()
plt.show()

# %%
text_rules = export_text(dt_pruned, 
                         feature_names=feature_cols
                        )

print(text_rules)
# Out:
# |--- rate_201_251ms <= 10.00
# |   |--- rate_251_301ms <= 10.00
# |   |   |--- rate_151_201ms <= 10.00
# |   |   |   |--- rate_101_151ms <= 10.00
# |   |   |   |   |--- rate_1_51ms <= 10.00
# |   |   |   |   |   |--- class: back
# |   |   |   |   |--- rate_1_51ms >  10.00
# |   |   |   |   |   |--- class: back
# |   |   |   |--- rate_101_151ms >  10.00
# |   |   |   |   |--- rate_51_101ms <= 10.00
# |   |   |   |   |   |--- class: up
# |   |   |   |   |--- rate_51_101ms >  10.00
# |   |   |   |   |   |--- class: back
# |   |   |--- rate_151_201ms >  10.00
# |   |   |   |--- rate_151_201ms <= 30.00
# |   |   |   |   |--- rate_301_351ms <= 10.00
# |   |   |   |   |   |--- class: back
# |   |   |   |   |--- rate_301_351ms >  10.00
# |   |   |   |   |   |--- class: up
# |   |   |   |--- rate_151_201ms >  30.00
# |   |   |   |   |--- rate_101_151ms <= 90.00
# |   |   |   |   |   |--- class: front
# |   |   |   |   |--- rate_101_151ms >  90.00
# ...

# %% [markdown]
# ## Results
#
# To address the first question, the support vector classifier tested whether the stimulus label (person identity) could be decoded from the neural firing rates in the peak response window. After tuning over several polynomial degrees and regularization strengths, the best performing model was a polynomial SVC of degree four with `C = 0.1`. Even this optimized classifier achieved accuracy values below five percent, only marginally above the four percent chance level for 25 way classification. The small gain, combined with the high polynomial degree needed to extract any structure, suggests extreme overfitting pressure and very weak linear separability in the chosen feature space.
#
# To address the second question, ridge regression was used to test whether stimulus labels (person identity and head orientation) could linearly predict the magnitude of neural firing in the 150–250 ms peak window. Cross validation selected a large regularization strength of alpha equals 1000, indicating the need for heavy shrinkage due to the noise and sparsity of the target variable. Even with this optimized model, the test $R^2$ was only 0.0036, meaning the predictors explained far less than one percent of the variance. Restricted models confirmed this pattern: identity alone explained approximately 0.0005 of the variance, while orientation explained approximately 0.0031, with only marginal improvement when combined. Ridge coefficients were uniformly near zero, reinforcing that neither stimulus dimension strongly modulates the overall firing magnitude in AM.
#
#
# Together, these results show that neither simple peak firing rates nor linear transformations of stimulus labels capture the information structure of the AM neural population. Both methods fail for different reasons: the classifier cannot separate identities because meaningful identity information is not expressed as consistent rate differences, while the regression model cannot predict firing magnitude because the underlying code is sparse and nonlinear. These outcomes are scientifically consistent with the known computational role of AM and set the stage for deeper analysis using full temporal structure and dimensionality reduction.
#
#
# ## Discussion
#
# From the results, it is clear that with extremely low, single-digit accuracy, facial recognition is not strongly predicted by the data at peak times in its current form. The most important challenge faced while addressing this question is the amount of computational effort that goes into training the SVC model, which makes it difficult to assess a large field of options. After significant pruning in the data, as well as my options for tuning, I may have lost a large amount of details and information. A way I would look into getting something out of this, if I have more time, would be to assess generalization over various facial orientations rather over the entire data. This way, I could reduce the amount of data I had for each face, and would be able to train this model more efficiently.
#
# The main takeaway from the ridge results is that AM population coding is not effectively captured by mean firing rates, emphasizing the need to analyze patterns across neurons rather than simple average activity. The poor model performance was scientifically valuable because the failure confirms known properties of AM, specifically that identity coding is sparse and nonlinear. This contrast highlights the potential of using full temporal patterns (like in the partner's classification method) over scalar summaries for decoding meaningful structure. Future analysis should shift to predicting spike counts in narrower bins or employing a nonlinear model to better capture the high-dimensional, sparse encoding used by AM neurons.

# %% [markdown]
# ## Author Contributions
#
# Lowell completed the classification task, while Arkesh completed the regression task. Both authors spent equals amounts of time on code development and textual context. Lowell spent more time on the background and motivation, while Arkesh spent more time on the results. This was a moderately successful collaboration, with moderate being the key term due to poor time management.
#
# Arkesh's feedback on Lowell: It was diffcult for me to schedule time with Lowell due to his massive commitments in 5 other classes. Apart from that, Lowell was resourceful and did his due diligence to the project. Lowell was also able to write code to make a data concatenation script which was pretty neat. Version control is his strength.
#
# Lowell's feedback on Arkesh: Arkesh is extremely knowledgeable and was able to think of the dataset in ways I struggle to. He is able to wrangle the dataset in his mind, and apply regularization in extremely complex ways. I do not have many critiques, but Arkesh did struggle simplifying his results and making them more communicable.

# %% [markdown]
# ## References
#
# [1] D. Y. Tsao, W. A. Freiwald, R. B. Tootell, and M. S. Livingstone, "A cortical region consisting entirely of face-selective cells," *Science*, vol. 311, no. 5670, pp. 670-674, Feb. 2006.
#
# [2] W. A. Freiwald and D. Y. Tsao, "Functional compartmentalization and viewpoint generalization within the macaque face-processing system," *Science*, vol. 330, no. 6005, pp. 845-851, Nov. 2010.
#
# [3] E. M. Meyers, M. Borzello, W. A. Freiwald, and D. Tsao, "Intelligent information loss: The coding of facial identity, head pose, and non-face information in the macaque face patch system," *J. Neurosci.*, vol. 35, no. 18, pp. 7069-7081, May 2015.
#
# ## Appendix
#
# ### Data Concatenation Code
#
# <a id='data-concatenation-code'></a>
#
# The following code was developed to generate a concatenated version of the dataset with all rasters combined vertically by selecting all files in data folder in the raster format and concatenating them using `pandas`.

# %% [raw]
# def concatenate_rasters(save=True):
#     search_path = "data/*.csv"
#     all_files = glob.glob(search_path, recursive=True)
#     processed_dfs = []
#     raster_files = [f for f in all_files if "raster_data" in f.lower()]
#     processed_dfs = []
#     for filename in raster_files:
#         df = pd.read_csv(filename)
#         site_id = filename.split('site')[1].replace('.csv', '')
#         df.insert(0, 'site', site_id)
#         processed_dfs.append(df)
#
#     data = pd.concat(processed_dfs, axis=0, ignore_index=True)
#     if save:
#         data.to_csv("data/data.csv", index=False)
#     return data
